# %% [markdown]
# # Homework 7: Sentiment Classification with Pre-trained and Re-trained GloVe Embeddings
#
# ## Due: Midnight on October 19th @ Midnight (with 2-hour grace period) and worth 85 points.
#
# In this notebook, we’ll continue with the investigation of text classification using "Bag of Embeddings" models and the IMDB movie review dataset.
# We'll focus on unfrozen embeddings, which refine the embedding space based on your dataset.
#
# You'll do three problems:
#
# * **Problem One:** Build a baseline model with unfrozen embeddings and experiment with architectural and training adjustments to improve performance.
# * **Problem Two:** Investigate how increasing the maximum message length and vocabulary size affects model accuracy and generalization.
# * **Problem Three:** Examine the impact of changing the embedding dimension on model performance.
#
#
# In each problem, you'll report your best validation accuracy and reflect on what you have learned.

# %% [markdown]
# ### Useful Imports

# %%
import numpy as np
import os
import matplotlib.pyplot as plt
import time
from collections import Counter


from pathlib import Path
import tensorflow as tf
from tensorflow.keras import layers, models, Input, Sequential
from tensorflow.keras.layers import Input, Embedding, GlobalAveragePooling1D, Dense
from tensorflow.keras.preprocessing import sequence
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.datasets import imdb
from sklearn.model_selection import train_test_split

from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping,LearningRateScheduler,ReduceLROnPlateau
from tensorflow.keras.optimizers.schedules import CosineDecay, ExponentialDecay
from tensorflow.keras.layers import LayerNormalization, MaxPooling2D,Dropout,GlobalAveragePooling2D,Dense
from tensorflow.keras.layers import Conv2D,BatchNormalization,Activation,GlobalMaxPooling1D, Flatten
from sklearn.model_selection import StratifiedShuffleSplit

from sklearn.model_selection import StratifiedShuffleSplit


# Reproducibility

random_seed = 42

np.random.seed(random_seed)
tf.random.set_seed(random_seed)

# utility code

from datetime import datetime

def format_hms(seconds):
    return time.strftime("%H:%M:%S", time.gmtime(seconds))

'''  How to time your code
# start timer
start_time = time.time()

<your code here>

# Record end time and print execution time
print(f"Execution Time: " + format_time(time.time()-start_time))
'''

os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'  # Suppresses INFO and WARNING messages

# %% [markdown]
# ### Utility function to plot learning curves and keep track of all results
#
# - Call `print_results()` to see listing of all results logged so far
# - We've also added  `

# %%
def plot_learning_curves(hist, title, verbose=True):

    val_losses = hist.history['val_loss']
    min_val_loss = min(val_losses)
    min_val_epoch = val_losses.index(min_val_loss)
    val_acc_at_min_loss = hist.history['val_accuracy'][min_val_epoch]

    epochs = range(1, len(val_losses) + 1)  # epoch numbers starting at 1

    fig, axs = plt.subplots(2, 1, figsize=(8, 8), sharex=True)

    # --- Loss Plot ---
    axs[0].plot(epochs, hist.history['loss'], label='train loss')
    axs[0].plot(epochs, hist.history['val_loss'], label='val loss')
    axs[0].scatter(min_val_epoch + 1, min_val_loss, color='red', marker='x', s=50, label='min val loss')
    axs[0].set_title(f'{title} - Categorical Cross-Entropy Loss')
    axs[0].set_ylabel('Loss')
    axs[0].legend()
    axs[0].grid(True)

    # --- Accuracy Plot ---
    axs[1].plot(epochs, hist.history['accuracy'], label='train acc')
    axs[1].plot(epochs, hist.history['val_accuracy'], label='val acc')
    axs[1].scatter(min_val_epoch + 1, val_acc_at_min_loss, color='red', marker='x', s=50, label='acc @ min val loss')
    axs[1].set_title(f'{title} - Accuracy')
    axs[1].set_xlabel('Epoch')
    axs[1].set_ylabel('Accuracy')
    axs[1].legend()
    axs[1].grid(True)
    axs[1].set_ylim(0, 1.05)

    plt.tight_layout()
    plt.show()

# %% [markdown]
# ###  Wrapper for training and testing
#
# #### Assumptions:
# - Early stopping is default, add other callbacks as needed
# - Uses "binary_crossentropy" for binary classification task.
# - Assumes `X_train,y_train,X_test,y_test` already defined, will access them as global variables.
# - If `X_val` and `y_val` defined, will use those, else assumes `validation_split = 0.2` in `fit`
#
#
# **Note:** See the end of the notebook for results and parameter settings.

# %%
def train_and_test(model,
                   title         = "Learning Curves",
                   epochs        = 200,                   # Just needs to be bigger than early stopping point
                   optimizer     = "Adam",
                   lr_schedule   = 1e-3,                  # Adam defaults
                   clipnorm      = None,
                   batch_size    = 128,
                   loss          = "binary_crossentropy",
                   metrics       = ["accuracy"],
                   use_early_stopping = True,
                   patience      = 10,
                   min_delta     = 0.0001,
                   callbacks     = [],                     # for extra callbacks other than early stopping
                   verbose       = 0,
                   return_history = False
                  ):

    print(f"\n{title}\n")

    if optimizer == "Adam":
        opt = Adam(learning_rate=lr_schedule,clipnorm=clipnorm)
    else:
        opt = optimizer

    #Compiling the model
    model.compile(optimizer = opt,
                  loss      = loss,
                  metrics   = metrics
                 )



    if use_early_stopping:
        early_stop = EarlyStopping(
            monitor              = 'val_loss',
            patience             = patience,
            min_delta            = min_delta,
            restore_best_weights = True,               # this will mean that the model which produced the smallest validation loss will be returned
            verbose              = verbose
        )
        cbs=[early_stop] + callbacks
    else:
        cbs=callbacks

    # start timer
    start = time.time()

    # Fit the model with early stopping
    # If X_val defined, then  use it, else assume val is split from train

    if 'X_val' in globals():
        history = model.fit(X_train, y_train,
                            epochs=epochs,
                            batch_size=batch_size,
                            validation_data=(X_val, y_val),
                            callbacks=cbs,
                            verbose=verbose
                           )
    else:
        history = model.fit(X_train, y_train,
                            epochs=epochs,
                            batch_size=batch_size,
                            validation_split=0.2,
                            callbacks=cbs,
                            verbose=verbose
                           )

    # Plot training history
    plot_learning_curves(history, title=title)

    # Find epoch with minimum validation loss
    min_val_epoch = np.argmin(history.history['val_loss'])
    # Retrieve the values at that epoch
    min_val_loss = history.history['val_loss'][min_val_epoch]
    # Get corresponding validation accuracy at that epoch
    val_acc_at_min_loss = history.history['val_accuracy'][min_val_epoch]

    # Evaluate on test data
    test_loss, test_accuracy = model.evaluate(X_test, y_test, verbose=0)

    # Record end time and print execution time
    end = time.time()
    print(f"\nExecution Time: " + format_hms(end-start))

    # Print out results

    print(f"\nFinal Training Loss:            {history.history['loss'][-1]:.4f}")
    print(f"Final Training Accuracy:        {history.history['accuracy'][-1]:.4f}")
    print(f"Final Validation Loss:          {history.history['val_loss'][-1]:.4f}")
    print(f"Final Validation Accuracy:      {history.history['val_accuracy'][-1]:.4f}")
    print(f"Minimum Validation Loss:        {min_val_loss:.4f} (Epoch {min_val_epoch + 1})")
    print(f"Validation Accuracy @ Min Loss: {val_acc_at_min_loss:.4f}")

    print(f"\nTest Loss: {test_loss:.4f}")
    print(f"Test Accuracy: {test_accuracy:.4f}")

    print(f"\nValidation-Test Accuracy Gap: {abs(val_acc_at_min_loss - test_accuracy):.6f}")

    # Store accuracy in results
    results[title] = (val_acc_at_min_loss,min_val_epoch + 1)

    # Store all information about run in parameter_settings

    global parameter_settings
    entry = {
        "title": title,
        "timestamp": datetime.now().isoformat(timespec="seconds"),
        "epochs": int(epochs),
        "optimizer": optimizer,
        "lr_schedule": lr_schedule,
        "clipnorm": clipnorm,
        "loss": loss,
        "batch_size": batch_size,
        "use_early_stopping": use_early_stopping,
        "patience": patience,
        "min_delta": min_delta,
        "callbacks": _summarize_callbacks(callbacks),
        "Final Training Loss" : history.history['loss'][-1],
        "Final Training Accuracy" : history.history['accuracy'][-1],
        "Final Val Loss" : history.history['val_loss'][-1],
        "Final Val Accuracy" : history.history['val_accuracy'][-1],
        "Min Val Loss" : min_val_loss,
        "Min Val Loss Epoch" : min_val_epoch,
        "Val Acc @ Min Loss" : val_acc_at_min_loss,
        "Test Loss" : test_loss,
        "Test Acc" : test_accuracy,
        "Val-Test Accuracy Gap:" : abs(val_acc_at_min_loss - test_accuracy)
    }
    parameter_settings.setdefault(title, []).append(entry)

    if return_history:
        return history

def _summarize_callbacks(cbs):
    if cbs is None:
        return None
    out = []
    for cb in cbs:
        name = getattr(cb, "__class__", type(cb)).__name__
        info = {"class": name}
        # grab a few common attributes if present
        for attr in ("monitor", "mode", "patience", "min_delta",
                     "factor", "min_lr", "verbose", "cooldown"):
            if hasattr(cb, attr):
                info[attr] = getattr(cb, attr)
        out.append(info)
    return out

results = {}
parameter_settings = {}

def print_results():
    for title, (acc, ep) in sorted(results.items(),
                                   key=lambda kv: kv[1][0],   # kv[1] is (acc, epoch); [0] is acc
                                   reverse=True
                                  ):
        print(f"{title:<40}\t{acc:.4f}\t{ep}")

# %%
reduce_lr = ReduceLROnPlateau(
    monitor='val_loss',    # Quantity to be monitored.
    factor=0.5,            # Factor by which the learning rate will be reduced.
                           # new_lr = lr * factor
    patience=5,            # Number of epochs with no improvement
                           # after which learning rate will be reduced.
    min_delta=1e-5,        # Threshold for measuring the new optimum,
                           # to only focus on significant changes.
    cooldown=0,            # Number of epochs to wait before resuming
                           # normal operation after lr has been reduced.
    min_lr=1e-8,           # Lower bound on the learning rate.
    verbose=1,             # 0: quiet, 1: update messages.
)

#  put in the callbacks list:

#    train_and_test(model, title="Learning Curves",callbacks=[reduce_lr])

# %% [markdown]
# ### Prelude:  A little EDA: Distribution of review lengths and coverage by max vocabulary size
#
# You will use this to think about where the set parameters for maximum review length and the maximum number of unique tokens to use.

# %%
# IMDB vocab & length stats + coverage table + single coverage plot

from tensorflow.keras.datasets import imdb
from collections import Counter
import numpy as np
import matplotlib.pyplot as plt

# ---------------------------------------
# Load IMDB with NO cap (so we can measure coverage fairly)
# ---------------------------------------
(X_tr, y_tr), _ = imdb.load_data()

# ---------------------------------------
# 1) Global vocab stats (from Keras word_index)
# ---------------------------------------
word_index = imdb.get_word_index()  # mapping: word -> rank (lower rank = more frequent)
total_unique_words_corpus = len(word_index)  # across the full IMDB corpus Keras ships
print(f"Total unique words in Keras IMDB word_index (corpus-wide): {total_unique_words_corpus:,}")

# ---------------------------------------
# 2) Training review length stats + histogram (students pick max_text_length)
# ---------------------------------------
lengths = np.fromiter((len(r) for r in X_tr), dtype=np.int32)
print(f"Num training reviews: {len(lengths):,}")
print(f"Max length: {lengths.max():,} tokens")
print(f"Mean length: {lengths.mean():.1f} tokens")
print(f"Median length: {np.median(lengths):.0f} tokens")
for q in (90, 95, 99):
    print(f"{q}th percentile: {int(np.percentile(lengths, q))} tokens")

plt.figure(figsize=(8, 5))
plt.hist(lengths, bins=100, edgecolor='b')
plt.title("Histogram of IMDb Review Lengths (Training Set)")
plt.xlabel("Tokens per review")
plt.ylabel("Frequency")
plt.show()

# ---------------------------------------
# 3) Training-only frequency counts for real words (ids >= 3)
#    IMDB ID conventions: 0=<PAD>, 1=<START>, 2=<OOV>, >=3 actual words
# ---------------------------------------
def iter_tokens(seqs):
    for s in seqs:
        for t in s:
            yield t

train_counts = Counter(t for t in iter_tokens(X_tr) if t >= 3)

# Frequency list (descending) and cumulative token coverage
freqs = np.array(sorted(train_counts.values(), reverse=True), dtype=np.int64)
cum_tokens = np.cumsum(freqs)
total_tokens_train_words = int(cum_tokens[-1])
num_unique_words_train = int(len(freqs))

print(f"\nUnique word types in TRAIN (id >= 3): {num_unique_words_train:,}")
print(f"Total word tokens in TRAIN (id >= 3): {total_tokens_train_words:,}")

# ---------------------------------------
# 4) Coverage helper for a given num_words cap (Keras convention)
#    Valid word ids are [3, num_words_cap-1] → ranks [1 .. num_words_cap-3]
# ---------------------------------------
def coverage_for_cap(num_words_cap: int):
    kept_types = max(0, min(num_words_cap - 3, num_unique_words_train))
    kept_tokens = int(cum_tokens[kept_types - 1]) if kept_types > 0 else 0
    oov_tokens = total_tokens_train_words - kept_tokens
    coverage = kept_tokens / total_tokens_train_words if total_tokens_train_words > 0 else 0.0
    oov_share = oov_tokens / total_tokens_train_words if total_tokens_train_words > 0 else 0.0
    return dict(
        cap=num_words_cap,
        kept_tokens=kept_tokens,
        kept_types=kept_types,
        coverage=coverage,
        oov_share=oov_share
    )

# ---------------------------------------
# 5) Candidate vocab sizes: ASCII table + single coverage plot
# ---------------------------------------
candidate_caps = [2_000, 5_000, 10_000, 20_000, 30_000, 50_000,70_000,88_584]  # students can edit
rows = [coverage_for_cap(k) for k in candidate_caps]

print("\nCoverage metrics by candidate vocab size (TRAIN split):")
for r in rows:
    print(f"training_vocabulary_size={r['cap']:>6,} | coverage={r['coverage']*100:6.2f}% | "
          f"OOV={r['oov_share']*100:6.2f}% | types kept={r['kept_types']:>7,} | tokens kept={r['kept_tokens']:>10,}")

plt.figure(figsize=(7, 4.5))
plt.plot(candidate_caps, [r['coverage'] for r in rows], marker='o')
plt.xlabel("training_vocabulary_size (num_words)")
plt.ylabel("Token coverage on TRAIN (fraction)")
plt.title("Token Coverage vs. Vocab Size (TRAIN only)")
plt.grid(True, linestyle=":")
plt.ylim(0.75, 1.02)
plt.show()
# Out:
# Total unique words in Keras IMDB word_index (corpus-wide): 88,584
# Num training reviews: 25,000
# Max length: 2,494 tokens
# Mean length: 238.7 tokens
# Median length: 178 tokens
# 90th percentile: 467 tokens
# 95th percentile: 610 tokens
# 99th percentile: 926 tokens
# Unique word types in TRAIN (id >= 3): 88,583
# Total word tokens in TRAIN (id >= 3): 5,942,840
#
# Coverage metrics by candidate vocab size (TRAIN split):
# training_vocabulary_size= 2,000 | coverage= 82.84% | OOV= 17.16% | types kept=  1,997 | tokens kept= 4,922,766
# training_vocabulary_size= 5,000 | coverage= 90.03% | OOV=  9.97% | types kept=  4,997 | tokens kept= 5,350,551
# training_vocabulary_size=10,000 | coverage= 94.25% | OOV=  5.75% | types kept=  9,997 | tokens kept= 5,601,261
# training_vocabulary_size=20,000 | coverage= 97.22% | OOV=  2.78% | types kept= 19,997 | tokens kept= 5,777,376
# training_vocabulary_size=30,000 | coverage= 98.37% | OOV=  1.63% | types kept= 29,997 | tokens kept= 5,846,141
# training_vocabulary_size=50,000 | coverage= 99.32% | OOV=  0.68% | types kept= 49,997 | tokens kept= 5,902,246
# training_vocabulary_size=70,000 | coverage= 99.69% | OOV=  0.31% | types kept= 69,997 | tokens kept= 5,924,254
# training_vocabulary_size=88,584 | coverage=100.00% | OOV=  0.00% | types kept= 88,581 | tokens kept= 5,942,838

# %% [markdown]
# ### Load and preprocess dataset
#
# Here is where you can set the
# - `training_vocabulary_size` and
# - `max_text_length`

# %%
# Load and preprocess dataset into padded sequences of token IDs

training_vocabulary_size = 50_000               # <-----
max_text_length          = 5000                  # <-----

(X_tr, y_tr), (X_te, y_te) = imdb.load_data( num_words = training_vocabulary_size )

X  = np.concatenate([X_tr, X_te], axis=0)
y  = np.concatenate([y_tr, y_te], axis=0)

# 80 / 20 stratified split

X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.2,
    random_state=random_seed,
    stratify=y
)



X_train = pad_sequences(
    X_train,
    maxlen=max_text_length,
    padding='post',
    truncating='post'
)

X_test = pad_sequences(
    X_test,
    maxlen=max_text_length,
    padding='post',
    truncating='post'
)


X_train.shape,X_test.shape
# Out:
# ((40000, 5000), (10000, 5000))

# %% [markdown]
# ### Build the embedding matrix
#
# Here is where you can set
# - `embedding_dimension`

# %%
#  Build embedding matrix


embedding_dimension = 200                     # <-----

word_index      = imdb.get_word_index()

glove_path = Path(f"glove.6B.{embedding_dimension}d.txt")

embeddings_index = {}
with glove_path.open(encoding='utf8') as f:
    for line in f:
        word, *vec = line.split()
        embeddings_index[word] = np.asarray(vec, dtype='float32')


# Build embedding matrix

embedding_matrix = np.zeros((training_vocabulary_size, embedding_dimension))

for word, raw_idx in word_index.items():
    idx = raw_idx + 3                            # shift by 3 to match Keras’s token IDs
    if idx < training_vocabulary_size:
        vec = embeddings_index.get(word)
        if vec is not None:
            embedding_matrix[idx] = vec

# %% [markdown]
# ### Baseline Model from the Coding Notebook

# %%
model_baseline_frozen = Sequential([
    Input(shape=(max_text_length,), dtype='int32'),   # each sample is a sequence of max_text_length integers, e.g., 500
    Embedding(
        input_dim  = training_vocabulary_size,
        output_dim = embedding_dimension,
        weights    = [embedding_matrix],
        mask_zero  = True,                      # ignore <PAD> in pooling -- this makes a huge difference in training speed!
        trainable  = False                      # freeze or unfreeze embedding weights
    ),
    GlobalAveragePooling1D(),                        # take average along each dimension
    Dense(1, activation='sigmoid')
])


train_and_test(model_baseline_frozen,  lr_schedule=1e-2, title="model_baseline (frozen)")
# Out:
# model_baseline (frozen)
# Execution Time: 00:01:52
#
# Final Training Loss:            0.4551
# Final Training Accuracy:        0.7893
# Final Validation Loss:          0.4520
# Final Validation Accuracy:      0.7918
# Minimum Validation Loss:        0.4520 (Epoch 178)
# Validation Accuracy @ Min Loss: 0.7918
#
# Test Loss: 0.4464
# Test Accuracy: 0.7962
#
# Validation-Test Accuracy Gap: 0.004450

# %% [markdown]
# #### End of Template Code from Coding Notebook

# %% [markdown]
# ## Problem One: Baseline with Unfrozen Embeddings
#
# **ToDo:**
#
# 1. Establish a baseline for unfrozen embeddings by running the baseline model but with `trainable = True` to retrain the embeddings as it trains on the the classification task. You will use retrainable embeddings throughout the homework.
#
# 2. Now run 2-3 experiments to try to improve this baseline:
#
#     - Consider adding a Dense layer between the global average pooling and the output layer, with
#         - Your choice of size
#         - Your choice of L2 regularizatio (or not)
#         - Your choice of dropout (or not)
# 3. As needed, tweak the learning rate (try `1e-4`) and try it with or without Reduce on Plateau (you can tweak the parameters there as well)
# 4. Define your best model for unfrozen embeddings based on these experiments (you will use it in the remaining two problems)
# 5. Answer the graded questions
#
# **Note:** Generally, you will need a lower learning rate for retrainable embeddings.

# %%
# Your code here; add as many cells as you need

baseline_unfrozen = Sequential([
    Input(shape=(max_text_length,), dtype='int32'),
    Embedding(
        input_dim  = training_vocabulary_size,
        output_dim = embedding_dimension,
        weights    = [embedding_matrix],
        mask_zero  = True,
        trainable  = True
    ),
    GlobalAveragePooling1D(),
    Dense(1, activation='sigmoid')
])


train_and_test(baseline_unfrozen,  lr_schedule=1e-4, title="model_baseline (unfrozen)")
# Out:
# model_baseline (unfrozen)
# Execution Time: 00:01:37
#
# Final Training Loss:            0.1233
# Final Training Accuracy:        0.9633
# Final Validation Loss:          0.2412
# Final Validation Accuracy:      0.9039
# Minimum Validation Loss:        0.2409 (Epoch 101)
# Validation Accuracy @ Min Loss: 0.9050
#
# Test Loss: 0.2533
# Test Accuracy: 0.8998
#
# Validation-Test Accuracy Gap: 0.005200

# %%
uf_model_1 = Sequential([
    Input(shape=(max_text_length,), dtype='int32'),
    Embedding(
        input_dim  = training_vocabulary_size,
        output_dim = embedding_dimension,
        weights    = [embedding_matrix],
        mask_zero  = True,
        trainable  = True
    ),
    GlobalAveragePooling1D(),
    Dense(64, activation='relu'),
    Dense(1, activation='sigmoid')
])


train_and_test(uf_model_1,  lr_schedule=1e-4, title="unfrozen model 1 -- dense layer 64")
# Out:
# unfrozen model 1 -- dense layer 64
# Execution Time: 00:00:40
#
# Final Training Loss:            0.1109
# Final Training Accuracy:        0.9652
# Final Validation Loss:          0.2565
# Final Validation Accuracy:      0.9004
# Minimum Validation Loss:        0.2508 (Epoch 32)
# Validation Accuracy @ Min Loss: 0.8995
#
# Test Loss: 0.2632
# Test Accuracy: 0.8983
#
# Validation-Test Accuracy Gap: 0.001200

# %%
uf_model_2 = Sequential([
    Input(shape=(max_text_length,), dtype='int32'),
    Embedding(
        input_dim  = training_vocabulary_size,
        output_dim = embedding_dimension,
        weights    = [embedding_matrix],
        mask_zero  = True,
        trainable  = True
    ),
    GlobalAveragePooling1D(),
    Dense(64, activation='relu'),
    Dropout(0.5),
    Dense(1, activation='sigmoid')
])


train_and_test(uf_model_2,  lr_schedule=1e-4, title="unfrozen model 2 -- dense layer and dropout 0.5")
# Out:
# unfrozen model 2 -- dense layer and dropout 0.5
# Execution Time: 00:00:47
#
# Final Training Loss:            0.1130
# Final Training Accuracy:        0.9653
# Final Validation Loss:          0.2560
# Final Validation Accuracy:      0.9020
# Minimum Validation Loss:        0.2476 (Epoch 38)
# Validation Accuracy @ Min Loss: 0.9025
#
# Test Loss: 0.2604
# Test Accuracy: 0.8972
#
# Validation-Test Accuracy Gap: 0.005300

# %%
uf_model_3 = Sequential([
    Input(shape=(max_text_length,), dtype='int32'),
    Embedding(
        input_dim  = training_vocabulary_size,
        output_dim = embedding_dimension,
        weights    = [embedding_matrix],
        mask_zero  = True,
        trainable  = True
    ),
    GlobalAveragePooling1D(),
    Dense(128, activation='relu'),
    Dropout(0.3),
    Dense(1, activation='sigmoid')
])


train_and_test(uf_model_3,  lr_schedule=1e-4, title="unfrozen model 3 -- dense layer 128 and dropout 0.3")
# Out:
# unfrozen model 3 -- dense layer 128 and dropout 0.3
# Execution Time: 00:00:38
#
# Final Training Loss:            0.1108
# Final Training Accuracy:        0.9649
# Final Validation Loss:          0.2573
# Final Validation Accuracy:      0.9005
# Minimum Validation Loss:        0.2504 (Epoch 30)
# Validation Accuracy @ Min Loss: 0.8985
#
# Test Loss: 0.2646
# Test Accuracy: 0.8960
#
# Validation-Test Accuracy Gap: 0.002500

# %%
reduce_lr = ReduceLROnPlateau(
    monitor='val_loss',    # Quantity to be monitored.
    factor=0.5,            # Factor by which the learning rate will be reduced.
                           # new_lr = lr * factor
    patience=5,            # Number of epochs with no improvement
                           # after which learning rate will be reduced.
    min_delta=1e-5,        # Threshold for measuring the new optimum,
                           # to only focus on significant changes.
    cooldown=0,            # Number of epochs to wait before resuming
                           # normal operation after lr has been reduced.
    min_lr=1e-8,           # Lower bound on the learning rate.
    verbose=1,             # 0: quiet, 1: update messages.
)

uf_model_4 = Sequential([
    Input(shape=(max_text_length,), dtype='int32'),
    Embedding(
        input_dim  = training_vocabulary_size,
        output_dim = embedding_dimension,
        weights    = [embedding_matrix],
        mask_zero  = True,
        trainable  = True
    ),
    GlobalAveragePooling1D(),
    Dense(64, activation='relu'),
    Dropout(0.5),
    Dense(1, activation='sigmoid')
])


train_and_test(uf_model_4,  lr_schedule=1e-4, callbacks=[reduce_lr], title="unfrozen model 4 -- dense layer 64 and dropout 0.5 and reduce lr")
# Out:
# unfrozen model 4 -- dense layer 64 and dropout 0.5 and reduce lr
#
#
# Epoch 44: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
#
# Epoch 49: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# Execution Time: 00:00:48
#
# Final Training Loss:            0.1272
# Final Training Accuracy:        0.9600
# Final Validation Loss:          0.2524
# Final Validation Accuracy:      0.8996
# Minimum Validation Loss:        0.2491 (Epoch 39)
# Validation Accuracy @ Min Loss: 0.8984
#
# Test Loss: 0.2613
# Test Accuracy: 0.8982
#
# Validation-Test Accuracy Gap: 0.000175

# %%
reduce_lr = ReduceLROnPlateau(
    monitor='val_loss',    # Quantity to be monitored.
    factor=0.5,            # Factor by which the learning rate will be reduced.
                           # new_lr = lr * factor
    patience=8,            # Number of epochs with no improvement
                           # after which learning rate will be reduced.
    min_delta=1e-4,        # Threshold for measuring the new optimum,
                           # to only focus on significant changes.
    cooldown=0,            # Number of epochs to wait before resuming
                           # normal operation after lr has been reduced.
    min_lr=1e-8,           # Lower bound on the learning rate.
    verbose=1,             # 0: quiet, 1: update messages.
)

uf_model_5 = Sequential([
    Input(shape=(max_text_length,), dtype='int32'),
    Embedding(
        input_dim  = training_vocabulary_size,
        output_dim = embedding_dimension,
        weights    = [embedding_matrix],
        mask_zero  = True,
        trainable  = True
    ),
    GlobalAveragePooling1D(),
    Dense(64, activation='relu'),
    Dropout(0.5),
    Dense(1, activation='sigmoid')
])


train_and_test(uf_model_5,  lr_schedule=1e-4, callbacks=[reduce_lr], title="unfrozen model 5 -- dense layer 64 and dropout 0.5 and adj reduce lr")
# Out:
# unfrozen model 5 -- dense layer 64 and dropout 0.5 and adj reduce lr
#
#
# Epoch 47: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# Execution Time: 00:00:49
#
# Final Training Loss:            0.1142
# Final Training Accuracy:        0.9655
# Final Validation Loss:          0.2541
# Final Validation Accuracy:      0.8991
# Minimum Validation Loss:        0.2468 (Epoch 39)
# Validation Accuracy @ Min Loss: 0.9015
#
# Test Loss: 0.2603
# Test Accuracy: 0.8975
#
# Validation-Test Accuracy Gap: 0.004000

# %%
reduce_lr = ReduceLROnPlateau(
    monitor='val_loss',    # Quantity to be monitored.
    factor=0.5,            # Factor by which the learning rate will be reduced.
                           # new_lr = lr * factor
    patience=8,            # Number of epochs with no improvement
                           # after which learning rate will be reduced.
    min_delta=1e-3,        # Threshold for measuring the new optimum,
                           # to only focus on significant changes.
    cooldown=0,            # Number of epochs to wait before resuming
                           # normal operation after lr has been reduced.
    min_lr=1e-8,           # Lower bound on the learning rate.
    verbose=1,             # 0: quiet, 1: update messages.
)

uf_model_6 = Sequential([
    Input(shape=(max_text_length,), dtype='int32'),
    Embedding(
        input_dim  = training_vocabulary_size,
        output_dim = embedding_dimension,
        weights    = [embedding_matrix],
        mask_zero  = True,
        trainable  = True
    ),
    GlobalAveragePooling1D(),
    Dense(64, activation='relu'),
    Dropout(0.5),
    Dense(1, activation='sigmoid')
])


train_and_test(uf_model_6,  lr_schedule=1e-4, callbacks=[reduce_lr], title="unfrozen model 6 -- dense layer 64 and dropout 0.5 and adj reduce lr")
# Out:
# unfrozen model 6 -- dense layer 64 and dropout 0.5 and adj reduce lr
#
#
# Epoch 43: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# Execution Time: 00:00:46
#
# Final Training Loss:            0.1273
# Final Training Accuracy:        0.9607
# Final Validation Loss:          0.2538
# Final Validation Accuracy:      0.8982
# Minimum Validation Loss:        0.2505 (Epoch 38)
# Validation Accuracy @ Min Loss: 0.8988
#
# Test Loss: 0.2628
# Test Accuracy: 0.8967
#
# Validation-Test Accuracy Gap: 0.002050

# %%
reduce_lr = ReduceLROnPlateau(
    monitor='val_loss',    # Quantity to be monitored.
    factor=0.5,            # Factor by which the learning rate will be reduced.
                           # new_lr = lr * factor
    patience=8,            # Number of epochs with no improvement
                           # after which learning rate will be reduced.
    min_delta=1e-3,        # Threshold for measuring the new optimum,
                           # to only focus on significant changes.
    cooldown=0,            # Number of epochs to wait before resuming
                           # normal operation after lr has been reduced.
    min_lr=1e-8,           # Lower bound on the learning rate.
    verbose=1,             # 0: quiet, 1: update messages.
)

uf_model_7 = Sequential([
    Input(shape=(max_text_length,), dtype='int32'),
    Embedding(
        input_dim  = training_vocabulary_size,
        output_dim = embedding_dimension,
        weights    = [embedding_matrix],
        mask_zero  = True,
        trainable  = True
    ),
    GlobalAveragePooling1D(),
    Dense(128, activation='relu'),
    Dropout(0.5),
    Dense(1, activation='sigmoid')
])


train_and_test(uf_model_7,  lr_schedule=1e-4, callbacks=[reduce_lr], title="unfrozen model 7 -- dense layer 128 and dropout 0.5 and adj reduce lr")
# Out:
# unfrozen model 7 -- dense layer 128 and dropout 0.5 and adj reduce lr
#
#
# Epoch 39: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# Execution Time: 00:00:41
#
# Final Training Loss:            0.1154
# Final Training Accuracy:        0.9632
# Final Validation Loss:          0.2543
# Final Validation Accuracy:      0.9004
# Minimum Validation Loss:        0.2493 (Epoch 32)
# Validation Accuracy @ Min Loss: 0.9020
#
# Test Loss: 0.2628
# Test Accuracy: 0.8986
#
# Validation-Test Accuracy Gap: 0.003400

# %%
reduce_lr = ReduceLROnPlateau(
    monitor='val_loss',    # Quantity to be monitored.
    factor=0.2,            # Factor by which the learning rate will be reduced.
                           # new_lr = lr * factor
    patience=3,            # Number of epochs with no improvement
                           # after which learning rate will be reduced.
    min_delta=1e-4,        # Threshold for measuring the new optimum,
                           # to only focus on significant changes.
    cooldown=0,            # Number of epochs to wait before resuming
                           # normal operation after lr has been reduced.
    min_lr=1e-8,           # Lower bound on the learning rate.
    verbose=1,             # 0: quiet, 1: update messages.
)

uf_model_8 = Sequential([
    Input(shape=(max_text_length,), dtype='int32'),
    Embedding(
        input_dim  = training_vocabulary_size,
        output_dim = embedding_dimension,
        weights    = [embedding_matrix],
        mask_zero  = True,
        trainable  = True
    ),
    GlobalAveragePooling1D(),
    Dense(1, activation='sigmoid')
])


train_and_test(uf_model_8,  lr_schedule=1e-5, callbacks=[reduce_lr], title="unfrozen model 8 -- reduce lr only")
# Out:
# unfrozen model 8 -- reduce lr only
# Execution Time: 00:02:57
#
# Final Training Loss:            0.3905
# Final Training Accuracy:        0.8618
# Final Validation Loss:          0.4022
# Final Validation Accuracy:      0.8506
# Minimum Validation Loss:        0.4022 (Epoch 200)
# Validation Accuracy @ Min Loss: 0.8506
#
# Test Loss: 0.3991
# Test Accuracy: 0.8511
#
# Validation-Test Accuracy Gap: 0.000475

# %% [markdown]
# ### Graded Questions
#
# #### Question a1a:

# %%
# Set a1a to the validation accuracy for your best model found in this problem

a1a = 0.9050             # Replace 0.0 with your answer

# %%
# Graded Answer
# DO NOT change this cell in any way

print(f'a1a = {a1a:.4f}')
# Out:
# a1a = 0.9050

# %% [markdown]
# #### Question a1b: Describe below your experiments. What worked and what didn't?
#
# #### Your Answer Here:
#
# I tried a variety of experiments for this problem. The first one I tried was adding a Dense layer and a Dropout layer. Then, I adjusted the width of both layers. However, neither seemed to produce a better validation accuracy. I incorporated Reduce LR on Plateau as well without improvement. Ultimately, the model with the best validation accuracy was the baseline model.

# %% [markdown]
# ## Problem Two: Experiment with Maximum Message Length and Vocabulary Size (still unfrozen)
#
# We might expect that increasing the amount of data by increasing the maximum message length and the vocabulary size would improve results,
# but maybe not, or maybe not as much as you would expect. Let's find out!
#
# **ToDo:**
#
# 1. Start with your best model from Problem One
#
# 2. Consult the information shown in the EDA cells above, and run 2-3 experiments to try to improve this model by increasing either or both of:
#
#     - `max_text_length`, and
#     - `training_vocabulary_size`
# 3. As needed, tweak the learning rate and try it with or without Reduce on Plateau (you can tweak the parametera there as well)
# 4. Define your best model for use in Problem Three
# 5. Answer the graded questions
#
# **Note:** `train_and_test` accesses the training and testing files as globals. You can cut and paste copies of the cells which load, preprocess, and build the embeddings for the dataset,
# but you'll be **redefining the global names,** just be careful about the order in which you run cells. As an alternative, you can change the parameters in the code in the Prelude, and
# just run this problem here.

# %%
# Your code here; add as many cells as you need

txt_lgth_model = Sequential([
    Input(shape=(max_text_length,), dtype='int32'),
    Embedding(
        input_dim  = training_vocabulary_size,
        output_dim = embedding_dimension,
        weights    = [embedding_matrix],
        mask_zero  = True,
        trainable  = True
    ),
    GlobalAveragePooling1D(),
    Dense(1, activation='sigmoid')
])


train_and_test(txt_lgth_model,  lr_schedule=1e-4, title="adjusting max_text_length")
# Out:
# adjusting max_text_length
# Execution Time: 00:09:53
#
# Final Training Loss:            0.1219
# Final Training Accuracy:        0.9640
# Final Validation Loss:          0.2382
# Final Validation Accuracy:      0.9046
# Minimum Validation Loss:        0.2380 (Epoch 101)
# Validation Accuracy @ Min Loss: 0.9053
#
# Test Loss: 0.2509
# Test Accuracy: 0.9017
#
# Validation-Test Accuracy Gap: 0.003550

# %%
reduce_lr = ReduceLROnPlateau(
    monitor='val_loss',    # Quantity to be monitored.
    factor=0.5,            # Factor by which the learning rate will be reduced.
                           # new_lr = lr * factor
    patience=5,            # Number of epochs with no improvement
                           # after which learning rate will be reduced.
    min_delta=1e-5,        # Threshold for measuring the new optimum,
                           # to only focus on significant changes.
    cooldown=0,            # Number of epochs to wait before resuming
                           # normal operation after lr has been reduced.
    min_lr=1e-8,           # Lower bound on the learning rate.
    verbose=1,             # 0: quiet, 1: update messages.
)

txt_lgth_model_2 = Sequential([
    Input(shape=(max_text_length,), dtype='int32'),
    Embedding(
        input_dim  = training_vocabulary_size,
        output_dim = embedding_dimension,
        weights    = [embedding_matrix],
        mask_zero  = True,
        trainable  = True
    ),
    GlobalAveragePooling1D(),
    Dense(1, activation='sigmoid')
])


train_and_test(txt_lgth_model_2,  lr_schedule=1e-4, callbacks=[reduce_lr], title="adjusting max_text_length -- reduce lr")
# Out:
# adjusting max_text_length -- reduce lr
#
#
# Epoch 104: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# Execution Time: 00:09:47
#
# Final Training Loss:            0.1228
# Final Training Accuracy:        0.9637
# Final Validation Loss:          0.2382
# Final Validation Accuracy:      0.9068
# Minimum Validation Loss:        0.2380 (Epoch 100)
# Validation Accuracy @ Min Loss: 0.9069
#
# Test Loss: 0.2511
# Test Accuracy: 0.9021
#
# Validation-Test Accuracy Gap: 0.004775

# %%
reduce_lr = ReduceLROnPlateau(
    monitor='val_loss',    # Quantity to be monitored.
    factor=0.3,            # Factor by which the learning rate will be reduced.
                           # new_lr = lr * factor
    patience=5,            # Number of epochs with no improvement
                           # after which learning rate will be reduced.
    min_delta=1e-5,        # Threshold for measuring the new optimum,
                           # to only focus on significant changes.
    cooldown=0,            # Number of epochs to wait before resuming
                           # normal operation after lr has been reduced.
    min_lr=1e-8,           # Lower bound on the learning rate.
    verbose=1,             # 0: quiet, 1: update messages.
)

txt_lgth_model_3 = Sequential([
    Input(shape=(max_text_length,), dtype='int32'),
    Embedding(
        input_dim  = training_vocabulary_size,
        output_dim = embedding_dimension,
        weights    = [embedding_matrix],
        mask_zero  = True,
        trainable  = True
    ),
    GlobalAveragePooling1D(),
    Dense(1, activation='sigmoid')
])


train_and_test(txt_lgth_model_3,  lr_schedule=1e-4, callbacks=[reduce_lr], title="adjusting max_text_length -- reduce lr factor 0.3")
# Out:
# adjusting max_text_length -- reduce lr factor 0.3
#
#
# Epoch 106: ReduceLROnPlateau reducing learning rate to 2.9999999242136255e-05.
# Execution Time: 00:09:57
#
# Final Training Loss:            0.1229
# Final Training Accuracy:        0.9635
# Final Validation Loss:          0.2387
# Final Validation Accuracy:      0.9049
# Minimum Validation Loss:        0.2385 (Epoch 102)
# Validation Accuracy @ Min Loss: 0.9051
#
# Test Loss: 0.2503
# Test Accuracy: 0.9022
#
# Validation-Test Accuracy Gap: 0.002925

# %%
reduce_lr = ReduceLROnPlateau(
    monitor='val_loss',    # Quantity to be monitored.
    factor=0.8,            # Factor by which the learning rate will be reduced.
                           # new_lr = lr * factor
    patience=8,            # Number of epochs with no improvement
                           # after which learning rate will be reduced.
    min_delta=1e-5,        # Threshold for measuring the new optimum,
                           # to only focus on significant changes.
    cooldown=0,            # Number of epochs to wait before resuming
                           # normal operation after lr has been reduced.
    min_lr=1e-8,           # Lower bound on the learning rate.
    verbose=1,             # 0: quiet, 1: update messages.
)

txt_lgth_model_4 = Sequential([
    Input(shape=(max_text_length,), dtype='int32'),
    Embedding(
        input_dim  = training_vocabulary_size,
        output_dim = embedding_dimension,
        weights    = [embedding_matrix],
        mask_zero  = True,
        trainable  = True
    ),
    GlobalAveragePooling1D(),
    Dense(1, activation='sigmoid')
])


train_and_test(txt_lgth_model_4,  lr_schedule=1e-4, callbacks=[reduce_lr], title="adjusting max_text_length -- reduce lr factor 0.8")
# Out:
# adjusting max_text_length -- reduce lr factor 0.8
# Execution Time: 00:09:57
#
# Final Training Loss:            0.1225
# Final Training Accuracy:        0.9635
# Final Validation Loss:          0.2382
# Final Validation Accuracy:      0.9054
# Minimum Validation Loss:        0.2380 (Epoch 103)
# Validation Accuracy @ Min Loss: 0.9059
#
# Test Loss: 0.2497
# Test Accuracy: 0.9035
#
# Validation-Test Accuracy Gap: 0.002375

# %% [markdown]
# ### Graded Questions

# %%
# Set a1a to the validation accuracy for your best model found in this problem

a2a = 0.9069             # Replace 0.0 with your answer

# %%
# Graded Answer
# DO NOT change this cell in any way

print(f'a2a = {a2a:.4f}')
# Out:
# a2a = 0.9069

# %% [markdown]
# #### Question a2b: Describe below your experiments. What effect did your changes to the dataset have? Did it help as you as you expected?
#
# #### Your Answer Here:
#
# I only attempted to increase the max_text_length to 5000. This only slightly improved the validation accuracy compared to the model in problem one. However, after adding reduce LR on plateau, the validation accuracy had some improvement. I attempted to adjust some of the hyperparameters of reduce lr to improve the model, but the original hyperparameters produced the best model.

# %% [markdown]
# ## Problem Three: Experiment with the Embedding Dimension  (still unfrozen)
#
# We might expect that increasing the embedding dimension would improve your results!
# Again, maybe not, or maybe not as much as you would expect. Let's find out!
#
# **ToDo:**
#
# 1. Start with your best model from Problem Two (which used an embedding dimension of 100)
# 2. Try an embedding dimension of 300 to see the effect. (Optional: Try 50 and 200 as well.)
# 3. As necessary weak the learning rate and try it with or without Reduce on Plateau (you can tweak the parameters there as well)
# 4. Answer the graded questions

# %%
# Your code here; add as many cells as you need

reduce_lr = ReduceLROnPlateau(
    monitor='val_loss',    # Quantity to be monitored.
    factor=0.5,            # Factor by which the learning rate will be reduced.
                           # new_lr = lr * factor
    patience=5,            # Number of epochs with no improvement
                           # after which learning rate will be reduced.
    min_delta=1e-5,        # Threshold for measuring the new optimum,
                           # to only focus on significant changes.
    cooldown=0,            # Number of epochs to wait before resuming
                           # normal operation after lr has been reduced.
    min_lr=1e-8,           # Lower bound on the learning rate.
    verbose=1,             # 0: quiet, 1: update messages.
)

embd_model_300 = Sequential([
    Input(shape=(max_text_length,), dtype='int32'),
    Embedding(
        input_dim  = training_vocabulary_size,
        output_dim = embedding_dimension,
        weights    = [embedding_matrix],
        mask_zero  = True,
        trainable  = True
    ),
    GlobalAveragePooling1D(),
    Dense(1, activation='sigmoid')
])


train_and_test(embd_model_300,  lr_schedule=1e-4, callbacks=[reduce_lr], title="embedded model -- 300")
# Out:
# embedded model -- 300
#
#
# Epoch 62: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# Execution Time: 00:18:25
#
# Final Training Loss:            0.1189
# Final Training Accuracy:        0.9651
# Final Validation Loss:          0.2393
# Final Validation Accuracy:      0.9053
# Minimum Validation Loss:        0.2385 (Epoch 57)
# Validation Accuracy @ Min Loss: 0.9056
#
# Test Loss: 0.2508
# Test Accuracy: 0.9023
#
# Validation-Test Accuracy Gap: 0.003325

# %%
reduce_lr = ReduceLROnPlateau(
    monitor='val_loss',    # Quantity to be monitored.
    factor=0.5,            # Factor by which the learning rate will be reduced.
                           # new_lr = lr * factor
    patience=5,            # Number of epochs with no improvement
                           # after which learning rate will be reduced.
    min_delta=1e-5,        # Threshold for measuring the new optimum,
                           # to only focus on significant changes.
    cooldown=0,            # Number of epochs to wait before resuming
                           # normal operation after lr has been reduced.
    min_lr=1e-8,           # Lower bound on the learning rate.
    verbose=1,             # 0: quiet, 1: update messages.
)

embd_model_50 = Sequential([
    Input(shape=(max_text_length,), dtype='int32'),
    Embedding(
        input_dim  = training_vocabulary_size,
        output_dim = embedding_dimension,
        weights    = [embedding_matrix],
        mask_zero  = True,
        trainable  = True
    ),
    GlobalAveragePooling1D(),
    Dense(1, activation='sigmoid')
])


train_and_test(embd_model_50,  lr_schedule=1e-4, callbacks=[reduce_lr], title="embedded model -- 50")
# Out:
# embedded model -- 50
#
#
# Epoch 138: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# Execution Time: 00:05:00
#
# Final Training Loss:            0.1230
# Final Training Accuracy:        0.9635
# Final Validation Loss:          0.2374
# Final Validation Accuracy:      0.9047
# Minimum Validation Loss:        0.2373 (Epoch 134)
# Validation Accuracy @ Min Loss: 0.9049
#
# Test Loss: 0.2501
# Test Accuracy: 0.9007
#
# Validation-Test Accuracy Gap: 0.004175

# %%
reduce_lr = ReduceLROnPlateau(
    monitor='val_loss',    # Quantity to be monitored.
    factor=0.5,            # Factor by which the learning rate will be reduced.
                           # new_lr = lr * factor
    patience=5,            # Number of epochs with no improvement
                           # after which learning rate will be reduced.
    min_delta=1e-5,        # Threshold for measuring the new optimum,
                           # to only focus on significant changes.
    cooldown=0,            # Number of epochs to wait before resuming
                           # normal operation after lr has been reduced.
    min_lr=1e-8,           # Lower bound on the learning rate.
    verbose=1,             # 0: quiet, 1: update messages.
)

embd_model_200 = Sequential([
    Input(shape=(max_text_length,), dtype='int32'),
    Embedding(
        input_dim  = training_vocabulary_size,
        output_dim = embedding_dimension,
        weights    = [embedding_matrix],
        mask_zero  = True,
        trainable  = True
    ),
    GlobalAveragePooling1D(),
    Dense(1, activation='sigmoid')
])


train_and_test(embd_model_200,  lr_schedule=1e-4, callbacks=[reduce_lr], title="embedded model -- 200")
# Out:
# embedded model -- 200
#
#
# Epoch 76: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# Execution Time: 00:19:29
#
# Final Training Loss:            0.1197
# Final Training Accuracy:        0.9645
# Final Validation Loss:          0.2384
# Final Validation Accuracy:      0.9065
# Minimum Validation Loss:        0.2379 (Epoch 72)
# Validation Accuracy @ Min Loss: 0.9065
#
# Test Loss: 0.2500
# Test Accuracy: 0.9020
#
# Validation-Test Accuracy Gap: 0.004500

# %% [markdown]
# ### Graded Questions

# %%
# Set a1a to the validation accuracy for your best model found in this problem

a3a = 0.9065             # Replace 0.0 with your answer

# %%
# Graded Answer
# DO NOT change this cell in any way

print(f'a3a = {a3a:.4f}')
# Out:
# a3a = 0.9065

# %% [markdown]
# #### Question a3b: Describe below your experiments. What effect did increasing the dimension from 100 to 300 have? Did it help as you as you expected?
#
# #### Your Answer Here:
#
# Increaseing the dimension from 100 to 300 actually had a negative effect on the model performance as validation accuracy decreased. However, I noticed that increasing the dimension from 100 to 200 showed some promise in providing a better validation accuracy.

# %%
print_results()
# Out:
# adjusting max_text_length -- reduce lr  	0.9069	100
# embedded model -- 200                   	0.9065	72
# adjusting max_text_length -- reduce lr factor 0.8	0.9059	103
# embedded model -- 300                   	0.9056	57
# adjusting max_text_length               	0.9053	101
# adjusting max_text_length -- reduce lr factor 0.3	0.9051	102
# model_baseline (unfrozen)               	0.9050	101
# embedded model -- 50                    	0.9049	134
# unfrozen model 2 -- dense layer and dropout 0.5	0.9025	38
# unfrozen model 7 -- dense layer 128 and dropout 0.5 and adj reduce lr	0.9020	32
# unfrozen model 5 -- dense layer 64 and dropout 0.5 and adj reduce lr	0.9015	39
# unfrozen model 1 -- dense layer 64      	0.8995	32
# unfrozen model 6 -- dense layer 64 and dropout 0.5 and adj reduce lr	0.8988	38
# unfrozen model 3 -- dense layer 128 and dropout 0.3	0.8985	30
# unfrozen model 4 -- dense layer 64 and dropout 0.5 and reduce lr	0.8984	39
# unfrozen model 7 -- dense layer 256 and dropout 0.5 and adj reduce lr	0.8975	29
# unfrozen model 8 -- reduce lr only      	0.8506	200
# model_baseline (frozen)                 	0.7918	178

# %%
# This will have recorded details of all your experiments

parameter_settings
# Out:
# {'model_baseline (frozen)': [{'title': 'model_baseline (frozen)',
#    'timestamp': '2025-10-15T05:21:09',
#    'epochs': 200,
#    'optimizer': 'Adam',
#    'lr_schedule': 0.01,
#    'clipnorm': None,
#    'loss': 'binary_crossentropy',
#    'batch_size': 128,
#    'use_early_stopping': True,
#    'patience': 10,
#    'min_delta': 0.0001,
#    'callbacks': [],
#    'Final Training Loss': 0.4551285207271576,
#    'Final Training Accuracy': 0.789312481880188,
#    'Final Val Loss': 0.4519534111022949,
#    'Final Val Accuracy': 0.7917500138282776,
#    'Min Val Loss': 0.4519534111022949,
#    'Min Val Loss Epoch': np.int64(177),
#    'Val Acc @ Min Loss': 0.7917500138282776,
#    'Test Loss': 0.44635382294654846,
#    'Test Acc': 0.7961999773979187,
#    'Val-Test Accuracy Gap:': 0.004449963569641113}],
#  'model_baseline (unfrozen)': [{'title': 'model_baseline (unfrozen)',
#    'timestamp': '2025-10-15T05:23:12',
#    'epochs': 200,
#    'optimizer': 'Adam',
#    'lr_schedule': 0.0001,
#    'clipnorm': None,
#    'loss': 'binary_crossentropy',
#    'batch_size': 128,
#    'use_early_stopping': True,
#    'patience': 10,
#    'min_delta': 0.0001,
#    'callbacks': [],
#    'Final Training Loss': 0.12331505864858627,
#    'Final Training Accuracy': 0.9633437395095825,
#    'Final Val Loss': 0.2412479817867279,
#    'Final Val Accuracy': 0.9038749933242798,
#    'Min Val Loss': 0.24090449512004852,
#    'Min Val Loss Epoch': np.int64(100),
#    'Val Acc @ Min Loss': 0.9049999713897705,
#    'Test Loss': 0.2533159554004669,
#    'Test Acc': 0.8998000025749207,
#    'Val-Test Accuracy Gap:': 0.0051999688148498535}],
#  'unfrozen model 1 -- dense layer 64': [{'title': 'unfrozen model 1 -- dense layer 64',
#    'timestamp': '2025-10-15T05:24:31',
#    'epochs': 200,
#    'optimizer': 'Adam',
#    'lr_schedule': 0.0001,
#    'clipnorm': None,
#    'loss': 'binary_crossentropy',
#    'batch_size': 128,
#    'use_early_stopping': True,
#    'patience': 10,
#    'min_delta': 0.0001,
#    'callbacks': [],
#    'Final Training Loss': 0.11094970256090164,
#    'Final Training Accuracy': 0.9651874899864197,
#    'Final Val Loss': 0.2564779222011566,
#    'Final Val Accuracy': 0.9003750085830688,
#    'Min Val Loss': 0.2507709860801697,
#    'Min Val Loss Epoch': np.int64(31),
#    'Val Acc @ Min Loss': 0.8995000123977661,
#    'Test Loss': 0.26323577761650085,
#    'Test Acc': 0.8982999920845032,
#    'Val-Test Accuracy Gap:': 0.0012000203132629395}],
#  'unfrozen model 2 -- dense layer and dropout 0.5': [{'title': 'unfrozen model 2 -- dense layer and dropout 0.5',
#    'timestamp': '2025-10-15T05:25:50',
#    'epochs': 200,
#    'optimizer': 'Adam',
#    'lr_schedule': 0.0001,
#    'clipnorm': None,
#    'loss': 'binary_crossentropy',
#    'batch_size': 128,
#    'use_early_stopping': True,
#    'patience': 10,
#    'min_delta': 0.0001,
#    'callbacks': [],
#    'Final Training Loss': 0.11302174627780914,
#    'Final Training Accuracy': 0.9652500152587891,
#    'Final Val Loss': 0.25595343112945557,
#    'Final Val Accuracy': 0.9020000100135803,
#    'Min Val Loss': 0.2476477026939392,
#    'Min Val Loss Epoch': np.int64(37),
#    'Val Acc @ Min Loss': 0.9024999737739563,
#    'Test Loss': 0.26044073700904846,
#    'Test Acc': 0.8971999883651733,
#    'Val-Test Accuracy Gap:': 0.005299985408782959}],
#  'unfrozen model 3 -- dense layer 128 and dropout 0.3': [{'title': 'unfrozen model 3 -- dense layer 128 and dropout 0.3',
#    'timestamp': '2025-10-15T05:28:12',
#    'epochs': 200,
#    'optimizer': 'Adam',
#    'lr_schedule': 0.0001,
#    'clipnorm': None,
#    'loss': 'binary_crossentropy',
#    'batch_size': 128,
#    'use_early_stopping': True,
#    'patience': 10,
#    'min_delta': 0.0001,
#    'callbacks': [],
#    'Final Training Loss': 0.1108185201883316,
#    'Final Training Accuracy': 0.9649375081062317,
#    'Final Val Loss': 0.25725334882736206,
#    'Final Val Accuracy': 0.9004999995231628,
#    'Min Val Loss': 0.2503640651702881,
#    'Min Val Loss Epoch': np.int64(29),
#    'Val Acc @ Min Loss': 0.8985000252723694,
#    'Test Loss': 0.2646104693412781,
#    'Test Acc': 0.8960000276565552,
#    'Val-Test Accuracy Gap:': 0.002499997615814209}],
#  'unfrozen model 4 -- dense layer 64 and dropout 0.5 and reduce lr': [{'title': 'unfrozen model 4 -- dense layer 64 and dropout 0.5 and reduce lr',
#    'timestamp': '2025-10-15T05:30:09',
#    'epochs': 200,
#    'optimizer': 'Adam',
#    'lr_schedule': 0.0001,
#    'clipnorm': None,
#    'loss': 'binary_crossentropy',
#    'batch_size': 128,
#    'use_early_stopping': True,
#    'patience': 10,
#    'min_delta': 0.0001,
#    'callbacks': [{'class': 'ReduceLROnPlateau',
#      'monitor': 'val_loss',
#      'mode': 'auto',
#      'patience': 5,
#      'min_delta': 1e-05,
#      'factor': 0.5,
#      'min_lr': 1e-08,
#      'verbose': 1,
#      'cooldown': 0}],
#    'Final Training Loss': 0.12720680236816406,
#    'Final Training Accuracy': 0.9599687457084656,
#    'Final Val Loss': 0.2524336278438568,
#    'Final Val Accuracy': 0.8996250033378601,
#    'Min Val Loss': 0.24907882511615753,
#    'Min Val Loss Epoch': np.int64(38),
#    'Val Acc @ Min Loss': 0.8983749747276306,
#    'Test Loss': 0.2612597942352295,
#    'Test Acc': 0.8981999754905701,
#    'Val-Test Accuracy Gap:': 0.00017499923706054688}],
#  'unfrozen model 5 -- dense layer 64 and dropout 0.5 and adj reduce lr': [{'title': 'unfrozen model 5 -- dense layer 64 and dropout 0.5 and adj reduce lr',
#    'timestamp': '2025-10-15T05:33:41',
#    'epochs': 200,
#    'optimizer': 'Adam',
#    'lr_schedule': 0.0001,
#    'clipnorm': None,
#    'loss': 'binary_crossentropy',
#    'batch_size': 128,
#    'use_early_stopping': True,
#    'patience': 10,
#    'min_delta': 0.0001,
#    'callbacks': [{'class': 'ReduceLROnPlateau',
#      'monitor': 'val_loss',
#      'mode': 'auto',
#      'patience': 8,
#      'min_delta': 0.0001,
#      'factor': 0.5,
#      'min_lr': 1e-08,
#      'verbose': 1,
#      'cooldown': 0}],
#    'Final Training Loss': 0.11420447379350662,
#    'Final Training Accuracy': 0.9654687643051147,
#    'Final Val Loss': 0.2541090250015259,
#    'Final Val Accuracy': 0.8991249799728394,
#    'Min Val Loss': 0.2467782348394394,
#    'Min Val Loss Epoch': np.int64(38),
#    'Val Acc @ Min Loss': 0.9014999866485596,
#    'Test Loss': 0.2602880001068115,
#    'Test Acc': 0.8974999785423279,
#    'Val-Test Accuracy Gap:': 0.0040000081062316895}],
#  'unfrozen model 6 -- dense layer 64 and dropout 0.5 and adj reduce lr': [{'title': 'unfrozen model 6 -- dense layer 64 and dropout 0.5 and adj reduce lr',
#    'timestamp': '2025-10-15T05:37:15',
#    'epochs': 200,
#    'optimizer': 'Adam',
#    'lr_schedule': 0.0001,
#    'clipnorm': None,
#    'loss': 'binary_crossentropy',
#    'batch_size': 128,
#    'use_early_stopping': True,
#    'patience': 10,
#    'min_delta': 0.0001,
#    'callbacks': [{'class': 'ReduceLROnPlateau',
#      'monitor': 'val_loss',
#      'mode': 'auto',
#      'patience': 8,
#      'min_delta': 0.001,
#      'factor': 0.5,
#      'min_lr': 1e-08,
#      'verbose': 1,
#      'cooldown': 0}],
#    'Final Training Loss': 0.1208329126238823,
#    'Final Training Accuracy': 0.9619374871253967,
#    'Final Val Loss': 0.25478509068489075,
#    'Final Val Accuracy': 0.9021250009536743,
#    'Min Val Loss': 0.2508770525455475,
#    'Min Val Loss Epoch': np.int64(30),
#    'Val Acc @ Min Loss': 0.9006249904632568,
#    'Test Loss': 0.2642455995082855,
#    'Test Acc': 0.895799994468689,
#    'Val-Test Accuracy Gap:': 0.004824995994567871},
#   {'title': 'unfrozen model 6 -- dense layer 64 and dropout 0.5 and adj reduce lr',
#    'timestamp': '2025-10-15T05:39:36',
#    'epochs': 200,
#    'optimizer': 'Adam',
#    'lr_schedule': 0.0001,
#    'clipnorm': None,
#    'loss': 'binary_crossentropy',
#    'batch_size': 128,
#    'use_early_stopping': True,
#    'patience': 10,
#    'min_delta': 0.0001,
#    'callbacks': [{'class': 'ReduceLROnPlateau',
#      'monitor': 'val_loss',
#      'mode': 'auto',
#      'patience': 8,
#      'min_delta': 0.001,
#      'factor': 0.5,
#      'min_lr': 1e-08,
#      'verbose': 1,
#      'cooldown': 0}],
#    'Final Training Loss': 0.1273176372051239,
#    'Final Training Accuracy': 0.9606562256813049,
#    'Final Val Loss': 0.25378578901290894,
#    'Final Val Accuracy': 0.8982499837875366,
#    'Min Val Loss': 0.2504672110080719,
#    'Min Val Loss Epoch': np.int64(37),
#    'Val Acc @ Min Loss': 0.8987500071525574,
#    'Test Loss': 0.26284319162368774,
#    'Test Acc': 0.8967000246047974,
#    'Val-Test Accuracy Gap:': 0.0020499825477600098}],
#  'unfrozen model 7 -- dense layer 256 and dropout 0.5 and adj reduce lr': [{'title': 'unfrozen model 7 -- dense layer 256 and dropout 0.5 and adj reduce lr',
#    'timestamp': '2025-10-15T05:42:52',
#    'epochs': 200,
#    'optimizer': 'Adam',
#    'lr_schedule': 0.0001,
#    'clipnorm': None,
#    'loss': 'binary_crossentropy',
#    'batch_size': 128,
#    'use_early_stopping': True,
#    'patience': 10,
#    'min_delta': 0.0001,
#    'callbacks': [{'class': 'ReduceLROnPlateau',
#      'monitor': 'val_loss',
#      'mode': 'auto',
#      'patience': 8,
#      'min_delta': 0.001,
#      'factor': 0.2,
#      'min_lr': 1e-08,
#      'verbose': 1,
#      'cooldown': 0}],
#    'Final Training Loss': 0.11624976992607117,
#    'Final Training Accuracy': 0.9629374742507935,
#    'Final Val Loss': 0.2578544318675995,
#    'Final Val Accuracy': 0.8978750109672546,
#    'Min Val Loss': 0.25245600938796997,
#    'Min Val Loss Epoch': np.int64(28),
#    'Val Acc @ Min Loss': 0.8974999785423279,
#    'Test Loss': 0.2650715410709381,
#    'Test Acc': 0.8952999711036682,
#    'Val-Test Accuracy Gap:': 0.002200007438659668}],
#  'unfrozen model 7 -- dense layer 128 and dropout 0.5 and adj reduce lr': [{'title': 'unfrozen model 7 -- dense layer 128 and dropout 0.5 and adj reduce lr',
#    'timestamp': '2025-10-15T05:45:54',
#    'epochs': 200,
#    'optimizer': 'Adam',
#    'lr_schedule': 0.0001,
#    'clipnorm': None,
#    'loss': 'binary_crossentropy',
#    'batch_size': 128,
#    'use_early_stopping': True,
#    'patience': 10,
#    'min_delta': 0.0001,
#    'callbacks': [{'class': 'ReduceLROnPlateau',
#      'monitor': 'val_loss',
#      'mode': 'auto',
#      'patience': 8,
#      'min_delta': 0.001,
#      'factor': 0.2,
#      'min_lr': 1e-08,
#      'verbose': 1,
#      'cooldown': 0}],
#    'Final Training Loss': 0.12057329714298248,
#    'Final Training Accuracy': 0.9612812399864197,
#    'Final Val Loss': 0.25223758816719055,
#    'Final Val Accuracy': 0.9013749957084656,
#    'Min Val Loss': 0.24823126196861267,
#    'Min Val Loss Epoch': np.int64(31),
#    'Val Acc @ Min Loss': 0.9018750190734863,
#    'Test Loss': 0.26303747296333313,
#    'Test Acc': 0.8978999853134155,
#    'Val-Test Accuracy Gap:': 0.003975033760070801},
#   {'title': 'unfrozen model 7 -- dense layer 128 and dropout 0.5 and adj reduce lr',
#    'timestamp': '2025-10-15T05:47:13',
#    'epochs': 200,
#    'optimizer': 'Adam',
#    'lr_schedule': 0.0001,
#    'clipnorm': None,
#    'loss': 'binary_crossentropy',
#    'batch_size': 128,
#    'use_early_stopping': True,
#    'patience': 10,
#    'min_delta': 0.0001,
#    'callbacks': [{'class': 'ReduceLROnPlateau',
#      'monitor': 'val_loss',
#      'mode': 'auto',
#      'patience': 8,
#      'min_delta': 0.001,
#      'factor': 0.5,
#      'min_lr': 1e-08,
#      'verbose': 1,
#      'cooldown': 0}],
#    'Final Training Loss': 0.11515001207590103,
#    'Final Training Accuracy': 0.9642812609672546,
#    'Final Val Loss': 0.25696006417274475,
#    'Final Val Accuracy': 0.9011250138282776,
#    'Min Val Loss': 0.2511727511882782,
#    'Min Val Loss Epoch': np.int64(31),
#    'Val Acc @ Min Loss': 0.9003750085830688,
#    'Test Loss': 0.2652505338191986,
#    'Test Acc': 0.8932999968528748,
#    'Val-Test Accuracy Gap:': 0.007075011730194092},
#   {'title': 'unfrozen model 7 -- dense layer 128 and dropout 0.5 and adj reduce lr',
#    'timestamp': '2025-10-15T05:48:45',
#    'epochs': 200,
#    'optimizer': 'Adam',
#    'lr_schedule': 0.0001,
#    'clipnorm': None,
#    'loss': 'binary_crossentropy',
#    'batch_size': 128,
#    'use_early_stopping': True,
#    'patience': 10,
#    'min_delta': 0.0001,
#    'callbacks': [{'class': 'ReduceLROnPlateau',
#      'monitor': 'val_loss',
#      'mode': 'auto',
#      'patience': 8,
#      'min_delta': 0.001,
#      'factor': 0.2,
#      'min_lr': 1e-08,
#      'verbose': 1,
#      'cooldown': 0}],
#    'Final Training Loss': 0.11920030415058136,
#    'Final Training Accuracy': 0.9616249799728394,
#    'Final Val Loss': 0.2553642988204956,
#    'Final Val Accuracy': 0.8971250057220459,
#    'Min Val Loss': 0.25159719586372375,
#    'Min Val Loss Epoch': np.int64(30),
#    'Val Acc @ Min Loss': 0.8973749876022339,
#    'Test Loss': 0.26392337679862976,
#    'Test Acc': 0.8974000215530396,
#    'Val-Test Accuracy Gap:': 2.5033950805664062e-05},
#   {'title': 'unfrozen model 7 -- dense layer 128 and dropout 0.5 and adj reduce lr',
#    'timestamp': '2025-10-15T05:49:52',
#    'epochs': 200,
#    'optimizer': 'Adam',
#    'lr_schedule': 0.0001,
#    'clipnorm': None,
#    'loss': 'binary_crossentropy',
#    'batch_size': 128,
#    'use_early_stopping': True,
#    'patience': 10,
#    'min_delta': 0.0001,
#    'callbacks': [{'class': 'ReduceLROnPlateau',
#      'monitor': 'val_loss',
#      'mode': 'auto',
#      'patience': 8,
#      'min_delta': 0.001,
#      'factor': 0.5,
#      'min_lr': 1e-08,
#      'verbose': 1,
#      'cooldown': 0}],
#    'Final Training Loss': 0.11537748575210571,
#    'Final Training Accuracy': 0.9632499814033508,
#    'Final Val Loss': 0.25431862473487854,
#    'Final Val Accuracy': 0.9003750085830688,
#    'Min Val Loss': 0.24927014112472534,
#    'Min Val Loss Epoch': np.int64(31),
#    'Val Acc @ Min Loss': 0.9020000100135803,
#    'Test Loss': 0.2627619504928589,
#    'Test Acc': 0.8985999822616577,
#    'Val-Test Accuracy Gap:': 0.0034000277519226074}],
#  'unfrozen model 8 -- reduce lr only': [{'title': 'unfrozen model 8 -- reduce lr only',
#    'timestamp': '2025-10-15T05:54:51',
#    'epochs': 200,
#    'optimizer': 'Adam',
#    'lr_schedule': 0.0001,
#    'clipnorm': None,
#    'loss': 'binary_crossentropy',
#    'batch_size': 128,
#    'use_early_stopping': True,
#    'patience': 10,
#    'min_delta': 0.0001,
#    'callbacks': [{'class': 'ReduceLROnPlateau',
#      'monitor': 'val_loss',
#      'mode': 'auto',
#      'patience': 8,
#      'min_delta': 0.001,
#      'factor': 0.5,
#      'min_lr': 1e-08,
#      'verbose': 1,
#      'cooldown': 0}],
#    'Final Training Loss': 0.12966176867485046,
#    'Final Training Accuracy': 0.960812509059906,
#    'Final Val Loss': 0.24074241518974304,
#    'Final Val Accuracy': 0.9046249985694885,
#    'Min Val Loss': 0.24070292711257935,
#    'Min Val Loss Epoch': np.int64(103),
#    'Val Acc @ Min Loss': 0.9048749804496765,
#    'Test Loss': 0.25309139490127563,
#    'Test Acc': 0.9004999995231628,
#    'Val-Test Accuracy Gap:': 0.004374980926513672},
#   {'title': 'unfrozen model 8 -- reduce lr only',
#    'timestamp': '2025-10-15T05:59:06',
#    'epochs': 200,
#    'optimizer': 'Adam',
#    'lr_schedule': 0.0001,
#    'clipnorm': None,
#    'loss': 'binary_crossentropy',
#    'batch_size': 128,
#    'use_early_stopping': True,
#    'patience': 10,
#    'min_delta': 0.0001,
#    'callbacks': [{'class': 'ReduceLROnPlateau',
#      'monitor': 'val_loss',
#      'mode': 'auto',
#      'patience': 5,
#      'min_delta': 1e-05,
#      'factor': 0.5,
#      'min_lr': 1e-08,
#      'verbose': 1,
#      'cooldown': 0}],
#    'Final Training Loss': 0.12499872595071793,
#    'Final Training Accuracy': 0.9625312685966492,
#    'Final Val Loss': 0.24105244874954224,
#    'Final Val Accuracy': 0.9042500257492065,
#    'Min Val Loss': 0.2408718466758728,
#    'Min Val Loss Epoch': np.int64(102),
#    'Val Acc @ Min Loss': 0.9046249985694885,
#    'Test Loss': 0.25172826647758484,
#    'Test Acc': 0.9010999798774719,
#    'Val-Test Accuracy Gap:': 0.0035250186920166016},
#   {'title': 'unfrozen model 8 -- reduce lr only',
#    'timestamp': '2025-10-15T06:01:44',
#    'epochs': 200,
#    'optimizer': 'Adam',
#    'lr_schedule': 0.0001,
#    'clipnorm': None,
#    'loss': 'binary_crossentropy',
#    'batch_size': 128,
#    'use_early_stopping': True,
#    'patience': 10,
#    'min_delta': 0.0001,
#    'callbacks': [{'class': 'ReduceLROnPlateau',
#      'monitor': 'val_loss',
#      'mode': 'auto',
#      'patience': 3,
#      'min_delta': 1e-05,
#      'factor': 0.5,
#      'min_lr': 1e-05,
#      'verbose': 1,
#      'cooldown': 1}],
#    'Final Training Loss': 0.12575110793113708,
#    'Final Training Accuracy': 0.9620624780654907,
#    'Final Val Loss': 0.24062994122505188,
#    'Final Val Accuracy': 0.9036250114440918,
#    'Min Val Loss': 0.24043650925159454,
#    'Min Val Loss Epoch': np.int64(99),
#    'Val Acc @ Min Loss': 0.9041249752044678,
#    'Test Loss': 0.2521853744983673,
#    'Test Acc': 0.9014999866485596,
#    'Val-Test Accuracy Gap:': 0.002624988555908203},
#   {'title': 'unfrozen model 8 -- reduce lr only',
#    'timestamp': '2025-10-15T06:06:10',
#    'epochs': 200,
#    'optimizer': 'Adam',
#    'lr_schedule': 1e-05,
#    'clipnorm': None,
#    'loss': 'binary_crossentropy',
#    'batch_size': 128,
#    'use_early_stopping': True,
#    'patience': 10,
#    'min_delta': 0.0001,
#    'callbacks': [{'class': 'ReduceLROnPlateau',
#      'monitor': 'val_loss',
#      'mode': 'auto',
#      'patience': 8,
#      'min_delta': 0.0001,
#      'factor': 0.5,
#      'min_lr': 1e-05,
#      'verbose': 1,
#      'cooldown': 0}],
#    'Final Training Loss': 0.38793036341667175,
#    'Final Training Accuracy': 0.8641562461853027,
#    'Final Val Loss': 0.39981845021247864,
#    'Final Val Accuracy': 0.8514999747276306,
#    'Min Val Loss': 0.39981845021247864,
#    'Min Val Loss Epoch': np.int64(199),
#    'Val Acc @ Min Loss': 0.8514999747276306,
#    'Test Loss': 0.3974059224128723,
#    'Test Acc': 0.8503999710083008,
#    'Val-Test Accuracy Gap:': 0.001100003719329834},
#   {'title': 'unfrozen model 8 -- reduce lr only',
#    'timestamp': '2025-10-15T06:09:36',
#    'epochs': 200,
#    'optimizer': 'Adam',
#    'lr_schedule': 1e-05,
#    'clipnorm': None,
#    'loss': 'binary_crossentropy',
#    'batch_size': 128,
#    'use_early_stopping': True,
#    'patience': 10,
#    'min_delta': 0.0001,
#    'callbacks': [{'class': 'ReduceLROnPlateau',
#      'monitor': 'val_loss',
#      'mode': 'auto',
#      'patience': 8,
#      'min_delta': 0.0001,
#      'factor': 0.5,
#      'min_lr': 1e-08,
#      'verbose': 1,
#      'cooldown': 0}],
#    'Final Training Loss': 0.39254501461982727,
#    'Final Training Accuracy': 0.8593437671661377,
#    'Final Val Loss': 0.4041217565536499,
#    'Final Val Accuracy': 0.846750020980835,
#    'Min Val Loss': 0.4041217565536499,
#    'Min Val Loss Epoch': np.int64(199),
#    'Val Acc @ Min Loss': 0.846750020980835,
#    'Test Loss': 0.4011317491531372,
#    'Test Acc': 0.8474000096321106,
#    'Val-Test Accuracy Gap:': 0.0006499886512756348},
#   {'title': 'unfrozen model 8 -- reduce lr only',
#    'timestamp': '2025-10-15T06:13:35',
#    'epochs': 200,
#    'optimizer': 'Adam',
#    'lr_schedule': 1e-05,
#    'clipnorm': None,
#    'loss': 'binary_crossentropy',
#    'batch_size': 128,
#    'use_early_stopping': True,
#    'patience': 10,
#    'min_delta': 0.0001,
#    'callbacks': [{'class': 'ReduceLROnPlateau',
#      'monitor': 'val_loss',
#      'mode': 'auto',
#      'patience': 3,
#      'min_delta': 0.0001,
#      'factor': 0.2,
#      'min_lr': 1e-08,
#      'verbose': 1,
#      'cooldown': 0}],
#    'Final Training Loss': 0.39052873849868774,
#    'Final Training Accuracy': 0.8617812395095825,
#    'Final Val Loss': 0.40221285820007324,
#    'Final Val Accuracy': 0.8506249785423279,
#    'Min Val Loss': 0.40221285820007324,
#    'Min Val Loss Epoch': np.int64(199),
#    'Val Acc @ Min Loss': 0.8506249785423279,
#    'Test Loss': 0.39911597967147827,
#    'Test Acc': 0.8511000275611877,
#    'Val-Test Accuracy Gap:': 0.0004750490188598633}],
#  'adjusting max_text_length': [{'title': 'adjusting max_text_length',
#    'timestamp': '2025-10-15T06:30:22',
#    'epochs': 200,
#    'optimizer': 'Adam',
#    'lr_schedule': 0.0001,
#    'clipnorm': None,
#    'loss': 'binary_crossentropy',
#    'batch_size': 128,
#    'use_early_stopping': True,
#    'patience': 10,
#    'min_delta': 0.0001,
#    'callbacks': [],
#    'Final Training Loss': 0.12188363820314407,
#    'Final Training Accuracy': 0.9639999866485596,
#    'Final Val Loss': 0.2382381409406662,
#    'Final Val Accuracy': 0.9046249985694885,
#    'Min Val Loss': 0.23796135187149048,
#    'Min Val Loss Epoch': np.int64(100),
#    'Val Acc @ Min Loss': 0.9052500128746033,
#    'Test Loss': 0.25090309977531433,
#    'Test Acc': 0.9017000198364258,
#    'Val-Test Accuracy Gap:': 0.0035499930381774902}],
#  'adjusting max_text_length -- reduce lr': [{'title': 'adjusting max_text_length -- reduce lr',
#    'timestamp': '2025-10-15T07:06:27',
#    'epochs': 200,
#    'optimizer': 'Adam',
#    'lr_schedule': 0.0001,
#    'clipnorm': None,
#    'loss': 'binary_crossentropy',
#    'batch_size': 128,
#    'use_early_stopping': True,
#    'patience': 10,
#    'min_delta': 0.0001,
#    'callbacks': [{'class': 'ReduceLROnPlateau',
#      'monitor': 'val_loss',
#      'mode': 'auto',
#      'patience': 5,
#      'min_delta': 1e-05,
#      'factor': 0.5,
#      'min_lr': 1e-08,
#      'verbose': 1,
#      'cooldown': 0}],
#    'Final Training Loss': 0.12279047816991806,
#    'Final Training Accuracy': 0.9636562466621399,
#    'Final Val Loss': 0.23819589614868164,
#    'Final Val Accuracy': 0.9067500233650208,
#    'Min Val Loss': 0.23802700638771057,
#    'Min Val Loss Epoch': np.int64(99),
#    'Val Acc @ Min Loss': 0.9068750143051147,
#    'Test Loss': 0.2511146366596222,
#    'Test Acc': 0.9021000266075134,
#    'Val-Test Accuracy Gap:': 0.004774987697601318}],
#  'adjusting max_text_length -- reduce lr factor 0.3': [{'title': 'adjusting max_text_length -- reduce lr factor 0.3',
#    'timestamp': '2025-10-15T07:18:51',
#    'epochs': 200,
#    'optimizer': 'Adam',
#    'lr_schedule': 0.0001,
#    'clipnorm': None,
#    'loss': 'binary_crossentropy',
#    'batch_size': 128,
#    'use_early_stopping': True,
#    'patience': 10,
#    'min_delta': 0.0001,
#    'callbacks': [{'class': 'ReduceLROnPlateau',
#      'monitor': 'val_loss',
#      'mode': 'auto',
#      'patience': 5,
#      'min_delta': 1e-05,
#      'factor': 0.3,
#      'min_lr': 1e-08,
#      'verbose': 1,
#      'cooldown': 0}],
#    'Final Training Loss': 0.12292356044054031,
#    'Final Training Accuracy': 0.9634687304496765,
#    'Final Val Loss': 0.23866254091262817,
#    'Final Val Accuracy': 0.9048749804496765,
#    'Min Val Loss': 0.23851735889911652,
#    'Min Val Loss Epoch': np.int64(101),
#    'Val Acc @ Min Loss': 0.9051250219345093,
#    'Test Loss': 0.25030452013015747,
#    'Test Acc': 0.9021999835968018,
#    'Val-Test Accuracy Gap:': 0.0029250383377075195}],
#  'adjusting max_text_length -- reduce lr factor 0.8': [{'title': 'adjusting max_text_length -- reduce lr factor 0.8',
#    'timestamp': '2025-10-15T07:30:47',
#    'epochs': 200,
#    'optimizer': 'Adam',
#    'lr_schedule': 0.0001,
#    'clipnorm': None,
#    'loss': 'binary_crossentropy',
#    'batch_size': 128,
#    'use_early_stopping': True,
#    'patience': 10,
#    'min_delta': 0.0001,
#    'callbacks': [{'class': 'ReduceLROnPlateau',
#      'monitor': 'val_loss',
#      'mode': 'auto',
#      'patience': 8,
#      'min_delta': 1e-05,
#      'factor': 0.8,
#      'min_lr': 1e-08,
#      'verbose': 1,
#      'cooldown': 0}],
#    'Final Training Loss': 0.12245874851942062,
#    'Final Training Accuracy': 0.9635000228881836,
#    'Final Val Loss': 0.23822294175624847,
#    'Final Val Accuracy': 0.9053750038146973,
#    'Min Val Loss': 0.23796410858631134,
#    'Min Val Loss Epoch': np.int64(102),
#    'Val Acc @ Min Loss': 0.905875027179718,
#    'Test Loss': 0.24973157048225403,
#    'Test Acc': 0.9035000205039978,
#    'Val-Test Accuracy Gap:': 0.002375006675720215}],
#  'embedded model -- 300': [{'title': 'embedded model -- 300',
#    'timestamp': '2025-10-15T07:56:33',
#    'epochs': 200,
#    'optimizer': 'Adam',
#    'lr_schedule': 0.0001,
#    'clipnorm': None,
#    'loss': 'binary_crossentropy',
#    'batch_size': 128,
#    'use_early_stopping': True,
#    'patience': 10,
#    'min_delta': 0.0001,
#    'callbacks': [{'class': 'ReduceLROnPlateau',
#      'monitor': 'val_loss',
#      'mode': 'auto',
#      'patience': 5,
#      'min_delta': 1e-05,
#      'factor': 0.5,
#      'min_lr': 1e-08,
#      'verbose': 1,
#      'cooldown': 0}],
#    'Final Training Loss': 0.11894620954990387,
#    'Final Training Accuracy': 0.965093731880188,
#    'Final Val Loss': 0.2392970621585846,
#    'Final Val Accuracy': 0.9052500128746033,
#    'Min Val Loss': 0.23853297531604767,
#    'Min Val Loss Epoch': np.int64(56),
#    'Val Acc @ Min Loss': 0.9056249856948853,
#    'Test Loss': 0.2507750689983368,
#    'Test Acc': 0.9023000001907349,
#    'Val-Test Accuracy Gap:': 0.0033249855041503906}],
#  'embedded model -- 50': [{'title': 'embedded model -- 50',
#    'timestamp': '2025-10-15T08:02:07',
#    'epochs': 200,
#    'optimizer': 'Adam',
#    'lr_schedule': 0.0001,
#    'clipnorm': None,
#    'loss': 'binary_crossentropy',
#    'batch_size': 128,
#    'use_early_stopping': True,
#    'patience': 10,
#    'min_delta': 0.0001,
#    'callbacks': [{'class': 'ReduceLROnPlateau',
#      'monitor': 'val_loss',
#      'mode': 'auto',
#      'patience': 5,
#      'min_delta': 1e-05,
#      'factor': 0.5,
#      'min_lr': 1e-08,
#      'verbose': 1,
#      'cooldown': 0}],
#    'Final Training Loss': 0.12304545193910599,
#    'Final Training Accuracy': 0.9635000228881836,
#    'Final Val Loss': 0.23743095993995667,
#    'Final Val Accuracy': 0.9047499895095825,
#    'Min Val Loss': 0.23732903599739075,
#    'Min Val Loss Epoch': np.int64(133),
#    'Val Acc @ Min Loss': 0.9048749804496765,
#    'Test Loss': 0.25008684396743774,
#    'Test Acc': 0.9006999731063843,
#    'Val-Test Accuracy Gap:': 0.004175007343292236}],
#  'embedded model -- 200': [{'title': 'embedded model -- 200',
#    'timestamp': '2025-10-15T08:33:08',
#    'epochs': 200,
#    'optimizer': 'Adam',
#    'lr_schedule': 0.0001,
#    'clipnorm': None,
#    'loss': 'binary_crossentropy',
#    'batch_size': 128,
#    'use_early_stopping': True,
#    'patience': 10,
#    'min_delta': 0.0001,
#    'callbacks': [{'class': 'ReduceLROnPlateau',
#      'monitor': 'val_loss',
#      'mode': 'auto',
#      'patience': 5,
#      'min_delta': 1e-05,
#      'factor': 0.5,
#      'min_lr': 1e-08,
#      'verbose': 1,
#      'cooldown': 0}],
#    'Final Training Loss': 0.11966173350811005,
#    'Final Training Accuracy': 0.964468777179718,
#    'Final Val Loss': 0.23841114342212677,
#    'Final Val Accuracy': 0.906499981880188,
#    'Min Val Loss': 0.2379097044467926,
#    'Min Val Loss Epoch': np.int64(71),
#    'Val Acc @ Min Loss': 0.906499981880188,
#    'Test Loss': 0.2499959021806717,
#    'Test Acc': 0.9020000100135803,
#    'Val-Test Accuracy Gap:': 0.004499971866607666}]}
